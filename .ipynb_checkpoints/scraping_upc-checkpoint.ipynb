# %%
import re
import pandas as pd
import numpy as np
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup
import requests
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
#used for not getting blocked
header = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36','Referer':'https://www.amazon.com/'}

# %%
search_query = ['850320008411']
for query in search_query:
    url = 'https://www.amazon.com/s?k='+query
    print(url)
# Out:
# https://www.amazon.com/s?k=850320008411

# %%
search_response = requests.get(url,headers=header)

# %%
search_response.status_code
# Out:
# 200

# %%
#search_response.text

# %%
#search_response.cookies

# %%
#function
cookie = {}
def getAmazonSearch(search_query):
    for page in range(1,3):
        url = ('https://www.amazon.com/s?k='+search_query+'&page={}'.format(page))
        print(url)
        page = requests.get(url,headers=header)
        if page.status_code==200:
            return page
        else:
            return 'Error'

# %%
#product name
def Searchasin(asin):
    url = 'https://www.amazon.com/dp/'+asin
    print(url)
    page = requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return 'Error'

# %%
#function
def Searchreviews(review_link):
    url = 'https://www.amazon.com'+review_link
    print(url)
    page = requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return 'Error'

# %%
from bs4 import BeautifulSoup
product_names = []
response = getAmazonSearch('850320008411')
soup = BeautifulSoup(response.content)
for i in soup.findAll('span',{'class':'a-size-base-plus a-color-base a-text-normal'}):
    product_names.append(i.text)
#print(product_names)
len(product_names)
# Out:
# https://www.amazon.com/s?k=850320008411&page=1
# 10

# %%
data_asin = []
response = getAmazonSearch('850320008411')
soup = BeautifulSoup(response.content)
for i in soup.findAll('div',{'class':'s-result-item s-asin sg-col-0-of-12 sg-col-16-of-20 sg-col sg-col-12-of-16'}):
    data_asin.append(i['data-asin'])
len(data_asin)
print(data_asin)
# Out:
# https://www.amazon.com/s?k=850320008411&page=1
# ['B07B47WHCC']

# %%
response.status_code
# Out:
# 200

# %%
link = []
for i in range(len(data_asin)):
    response = Searchasin(data_asin[i])
    soup = BeautifulSoup(response.content)
    for i in soup.findAll('a',{'data-hook':'see-all-reviews-link-foot'}):
        link.append(i['href'])
print(link)
# Out:
# https://www.amazon.com/dp/B07B47WHCC
# ['/Stryve-Biltong-Garlic-Protein-2-25oz/product-reviews/B07B47WHCC/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews']

# %%
#reviews, profile name and ratings
profile_name = []
ratings = []
date = []
#tag = []

for j in range(len(link)):
    for k in range(1,3):
        response = Searchreviews(link[j]+'&pageNumber='+str(k))
        soup = BeautifulSoup(response.content)
        #soup1 = soup.findAll('div',{'class':'a-section review aok-relative'})
        #soup1 = BeautifulSoup(response.content)
        for l in soup.findAll('span',{'class':'a-profile-name'})[2:]:
            profile_name.append(l.text)
            for i in soup.findAll('i',{'data-hook':'review-star-rating'}):
                ratings.append(i.text)
                for m in soup.findAll('span',{'data-hook':'review-date'}):
                    date.append(m.text)
# Out:
# https://www.amazon.com/Stryve-Biltong-Garlic-Protein-2-25oz/product-reviews/B07B47WHCC/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.com/Stryve-Biltong-Garlic-Protein-2-25oz/product-reviews/B07B47WHCC/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2

# %%
list1 = ''
for j in range(len(link)):
    for k in range(1,3):
        response = Searchreviews(link[j]+'&pageNumber='+str(k))
        soup = BeautifulSoup(response.content) 
        for link1 in soup.findAll('a',{'data-hook':'review-title'}):
            list1 += link1.get('href')+ '\n'
            #list1.append(list1)
print(list1)
# Out:
# https://www.amazon.com/Stryve-Biltong-Garlic-Protein-2-25oz/product-reviews/B07B47WHCC/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.com/Stryve-Biltong-Garlic-Protein-2-25oz/product-reviews/B07B47WHCC/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# /gp/customer-reviews/R2MDYN7CSIEAZ5/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# /gp/customer-reviews/R31QHSMQT58S2Z/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# /gp/customer-reviews/R3R5FUG8C17P5P/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# /gp/customer-reviews/R25U1AS495T1MV/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# /gp/customer-reviews/RG7NMOY35E2XN/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# /gp/customer-reviews/R2HRCAMNGGE8XR/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# /gp/customer-reviews/R36QBRYO6CI8BE/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# /gp/customer-reviews/R1M6UIJFBW9BW2/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# /gp/customer-reviews/R3PBHRJ54E8MOD/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# /gp/customer-reviews/R1AHY24C25ALRV/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# /gp/customer-reviews/R1RKN2HJ4AREYL/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# /gp/customer-reviews/R28P73ZC3CPKQV/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# /gp/customer-reviews/R2E1NI1H80N9CP/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# /gp/customer-reviews/R39SEBSH70U309/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC

# %%
list2 = ''
for j in range(len(link)):
    for k in range(1,3):
        response = Searchreviews(link[j]+'&pageNumber='+str(k))
        soup = BeautifulSoup(response.content) 
        for link2 in soup.findAll('span',{'class':'a-size-base review-text review-text-content'}):
            list2 += link2.get_text()+'new_line'
print(list2)
# Out:
# https://www.amazon.com/Stryve-Biltong-Garlic-Protein-2-25oz/product-reviews/B07B47WHCC/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.com/Stryve-Biltong-Garlic-Protein-2-25oz/product-reviews/B07B47WHCC/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
#
#
#   I really wanted to like this . I bought the zesty garlic and it was so hot all I could do is run for the water. Very disappointed. Maybe a different flavor might be better.
#
# new_line
#
#   Our family chose this flavor because we all love garlic. Some found the garlic intensity a little weak but it was perfect for my taste. The jerky itself was chewy but not too hard. We like the smaller packages because we don't feel the need to consume the entire product within a few days.
#
# new_line
#
#   Overall product is pretty good. Yes some pieces can be pretty tough when you start chewing( doesn't really bother me). Zesty garlic is more of a slow burn, wish the flavor was more initially intense( personal preference). Interested in experimenting with other flavors offered
#
# new_line
#
#   Got the Zesty Garlic, was unimpressed. The clove in the ingredients was the only thing I could taste and the beef was not "melt in your mouth".
#
# new_line
#
#   it’s ok. I wouldn’t say anything fantastic. if it was thinner and crispy like bacon ? it would be perfect.
#
# new_line
#
#   When I received the item in question, it was stale and brittle.
#
# new_line
#
#   If you like the taste of garlic biltong, than this is for you. It was just not what I was expecting.
#
# new_line
#
#   This is an amazing product.  It tastes great and provides great protein for a low calorie count. I eat one of these small packages every day.
#
# new_line
#
#   This is really good biltong. My husband grew up eating biltong and he thinks that Stryve Biltong is great!
#
# new_line
#
#   Best darn biltong around,  zesty garlic the bomb!!!!!
#
# new_line
#
#   There's so much flavor. If you like garlic you'll love this! definitely one of my Stryve favorites!
#
# new_line
#
#   Thrilled to find a jerky type product without a bunch of added sugar!
#
# new_line
#
#   I love this stuff, has a very strong garlic taste that i love.
#
# new_line
#
#   The taste of spices were good along with the crunch, the down fall, way too SALTY.  I will not purchase again as watching my salt intake
#
# new_line

# %%
list3 = ''
for j in range(len(link)):
    for k in range(1,3):
        response = Searchreviews(link[j]+'&pageNumber='+str(k))
        soup = BeautifulSoup(response.content) 
        for link3 in soup.findAll('a',{'class':'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold'}):
            list3 += link3.get_text()+'new_line'
print(list3)
# Out:
# https://www.amazon.com/Stryve-Biltong-Garlic-Protein-2-25oz/product-reviews/B07B47WHCC/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.com/Stryve-Biltong-Garlic-Protein-2-25oz/product-reviews/B07B47WHCC/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
#
# Not flavorful just hot!
# new_line
# Tasty. Will try other flavors next.
# new_line
# Would buy again
# new_line
# Too much clove.
# new_line
# ok.
# new_line
# Not pleased!!!
# new_line
# Good but not great
# new_line
# Great taste and high protein.
# new_line
# Delicious!
# new_line
# Biltong much better than jerky
# new_line
# Soooo good!
# new_line
# Love this!
# new_line
# good stuff!!
# new_line
# Taste Good....but
# new_line

# %%
list4 = ''
for j in range(len(link)):
    for k in range(1,3):
        response = Searchreviews(link[j]+'&pageNumber='+str(k))
        soup = BeautifulSoup(response.content) 
        for link4 in soup.findAll('a',{'class':'a-profile'})[2:]:
            list4 += link4.get('href')+ '\n'
            #list1.append(list1)
print(list4)
# Out:
# https://www.amazon.com/Stryve-Biltong-Garlic-Protein-2-25oz/product-reviews/B07B47WHCC/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.com/Stryve-Biltong-Garlic-Protein-2-25oz/product-reviews/B07B47WHCC/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# /gp/profile/amzn1.account.AHXPZVHBSZ57EQGMUWNF6U7U65HQ/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# /gp/profile/amzn1.account.AE5D6UZUC6JD55ZAWHV37J5W4AHA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# /gp/profile/amzn1.account.AHXDOYOHN3A23CKJQ4JM3TCDEBPA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# /gp/profile/amzn1.account.AEQMH6YYDWVL36HN6N42U6D3A7TA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# /gp/profile/amzn1.account.AGUUZ6CRSSPZKDXFWPMZ6EICB2YA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# /gp/profile/amzn1.account.AEUIKB7FZCUX2XSPGRWDNM3VWZZQ/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# /gp/profile/amzn1.account.AEQWDRHX723U5CWRRPZWVPZ2L34A/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# /gp/profile/amzn1.account.AGMEWNTWIESLSPRU37YIGSAJENFA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# /gp/profile/amzn1.account.AE6DWABHKPCU7Q4PRZHKZLNH24DA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# /gp/profile/amzn1.account.AFKIFE5MZR3LD6AV6D4NKOA5EZAA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# /gp/profile/amzn1.account.AG27HEMGYJG75H7YZCCZACQ2PLNQ/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# /gp/profile/amzn1.account.AEACSIHPIHYVDLTNUXBO5WFM6RBQ/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# /gp/profile/amzn1.account.AGPEQZRSHE6IXGVPIMAULN4IK73Q/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# /gp/profile/amzn1.account.AEUV6C2INP77HLEXHFUFLI2VEGYA/ref=cm_cr_arp_d_gw_btm?ie=UTF8

# %%
def Convert1(string): 
    li = list(string.split("\n")) 
    return li
a = Convert1(list1)

# %%
def Convert2(string): 
    li = list(string.split("new_line")) 
    return li 
b = Convert2(list2)

# %%
def Convert3(string): 
    li = list(string.split("new_line")) 
    return li 
c = Convert3(list3)
print(c)
# Out:
# ['\nNot flavorful just hot!\n', '\nTasty. Will try other flavors next.\n', '\nWould buy again\n', '\nToo much clove.\n', '\nok.\n', '\nNot pleased!!!\n', '\nGood but not great\n', '\nGreat taste and high protein.\n', '\nDelicious!\n', '\nBiltong much better than jerky\n', '\nSoooo good!\n', '\nLove this!\n', '\ngood stuff!!\n', '\nTaste Good....but\n', '']

# %%
def Convert4(string): 
    li = list(string.split("\n")) 
    return li 
d = Convert4(list4)
print(d)
# Out:
# ['/gp/profile/amzn1.account.AHXPZVHBSZ57EQGMUWNF6U7U65HQ/ref=cm_cr_arp_d_gw_btm?ie=UTF8', '/gp/profile/amzn1.account.AE5D6UZUC6JD55ZAWHV37J5W4AHA/ref=cm_cr_arp_d_gw_btm?ie=UTF8', '/gp/profile/amzn1.account.AHXDOYOHN3A23CKJQ4JM3TCDEBPA/ref=cm_cr_arp_d_gw_btm?ie=UTF8', '/gp/profile/amzn1.account.AEQMH6YYDWVL36HN6N42U6D3A7TA/ref=cm_cr_arp_d_gw_btm?ie=UTF8', '/gp/profile/amzn1.account.AGUUZ6CRSSPZKDXFWPMZ6EICB2YA/ref=cm_cr_arp_d_gw_btm?ie=UTF8', '/gp/profile/amzn1.account.AEUIKB7FZCUX2XSPGRWDNM3VWZZQ/ref=cm_cr_arp_d_gw_btm?ie=UTF8', '/gp/profile/amzn1.account.AEQWDRHX723U5CWRRPZWVPZ2L34A/ref=cm_cr_arp_d_gw_btm?ie=UTF8', '/gp/profile/amzn1.account.AGMEWNTWIESLSPRU37YIGSAJENFA/ref=cm_cr_arp_d_gw_btm?ie=UTF8', '/gp/profile/amzn1.account.AE6DWABHKPCU7Q4PRZHKZLNH24DA/ref=cm_cr_arp_d_gw_btm?ie=UTF8', '/gp/profile/amzn1.account.AFKIFE5MZR3LD6AV6D4NKOA5EZAA/ref=cm_cr_arp_d_gw_btm?ie=UTF8', '/gp/profile/amzn1.account.AG27HEMGYJG75H7YZCCZACQ2PLNQ/ref=cm_cr_arp_d_gw_btm?ie=UTF8', '/gp/profile/amzn1.account.AEACSIHPIHYVDLTNUXBO5WFM6RBQ/ref=cm_cr_arp_d_gw_btm?ie=UTF8', '/gp/profile/amzn1.account.AGPEQZRSHE6IXGVPIMAULN4IK73Q/ref=cm_cr_arp_d_gw_btm?ie=UTF8', '/gp/profile/amzn1.account.AEUV6C2INP77HLEXHFUFLI2VEGYA/ref=cm_cr_arp_d_gw_btm?ie=UTF8', '']

# %%
df1 = pd.DataFrame(a,columns=['links'])
df1 = df1.iloc[:-1,:]
df1
# Out:
#                                                 links
# 0   /gp/customer-reviews/R2MDYN7CSIEAZ5/ref=cm_cr_...
# 1   /gp/customer-reviews/R31QHSMQT58S2Z/ref=cm_cr_...
# 2   /gp/customer-reviews/R3R5FUG8C17P5P/ref=cm_cr_...
# 3   /gp/customer-reviews/R25U1AS495T1MV/ref=cm_cr_...
# 4   /gp/customer-reviews/RG7NMOY35E2XN/ref=cm_cr_a...
# 5   /gp/customer-reviews/R2HRCAMNGGE8XR/ref=cm_cr_...
# 6   /gp/customer-reviews/R36QBRYO6CI8BE/ref=cm_cr_...
# 7   /gp/customer-reviews/R1M6UIJFBW9BW2/ref=cm_cr_...
# 8   /gp/customer-reviews/R3PBHRJ54E8MOD/ref=cm_cr_...
# 9   /gp/customer-reviews/R1AHY24C25ALRV/ref=cm_cr_...
# 10  /gp/customer-reviews/R1RKN2HJ4AREYL/ref=cm_cr_...
# 11  /gp/customer-reviews/R28P73ZC3CPKQV/ref=cm_cr_...
# 12  /gp/customer-reviews/R2E1NI1H80N9CP/ref=cm_cr_...
# 13  /gp/customer-reviews/R39SEBSH70U309/ref=cm_cr_...

# %%
df2 = pd.DataFrame(b,columns=['reviews'])
df2 = df2.iloc[:-1,:]
df2
# Out:
#                                               reviews
# 0   \n\n  I really wanted to like this . I bought ...
# 1   \n\n  Our family chose this flavor because we ...
# 2   \n\n  Overall product is pretty good. Yes some...
# 3   \n\n  Got the Zesty Garlic, was unimpressed. T...
# 4   \n\n  it’s ok. I wouldn’t say anything fantast...
# 5   \n\n  When I received the item in question, it...
# 6   \n\n  If you like the taste of garlic biltong,...
# 7   \n\n  This is an amazing product.  It tastes g...
# 8   \n\n  This is really good biltong. My husband ...
# 9   \n\n  Best darn biltong around,  zesty garlic ...
# 10  \n\n  There's so much flavor. If you like garl...
# 11  \n\n  Thrilled to find a jerky type product wi...
# 12  \n\n  I love this stuff, has a very strong gar...
# 13  \n\n  The taste of spices were good along with...

# %%
df3 = pd.DataFrame(c,columns=['tags'])
df3 = df3.iloc[:-1,:]
df3
# Out:
#                                        tags
# 0               \nNot flavorful just hot!\n
# 1   \nTasty. Will try other flavors next.\n
# 2                       \nWould buy again\n
# 3                       \nToo much clove.\n
# 4                                   \nok.\n
# 5                        \nNot pleased!!!\n
# 6                    \nGood but not great\n
# 7         \nGreat taste and high protein.\n
# 8                            \nDelicious!\n
# 9        \nBiltong much better than jerky\n
# 10                          \nSoooo good!\n
# 11                           \nLove this!\n
# 12                         \ngood stuff!!\n
# 13                    \nTaste Good....but\n

# %%
df4 = pd.DataFrame(d,columns=['userid_link'])
df4 = df4.iloc[:-1,:]
df4
# Out:
#                                           userid_link
# 0   /gp/profile/amzn1.account.AHXPZVHBSZ57EQGMUWNF...
# 1   /gp/profile/amzn1.account.AE5D6UZUC6JD55ZAWHV3...
# 2   /gp/profile/amzn1.account.AHXDOYOHN3A23CKJQ4JM...
# 3   /gp/profile/amzn1.account.AEQMH6YYDWVL36HN6N42...
# 4   /gp/profile/amzn1.account.AGUUZ6CRSSPZKDXFWPMZ...
# 5   /gp/profile/amzn1.account.AEUIKB7FZCUX2XSPGRWD...
# 6   /gp/profile/amzn1.account.AEQWDRHX723U5CWRRPZW...
# 7   /gp/profile/amzn1.account.AGMEWNTWIESLSPRU37YI...
# 8   /gp/profile/amzn1.account.AE6DWABHKPCU7Q4PRZHK...
# 9   /gp/profile/amzn1.account.AFKIFE5MZR3LD6AV6D4N...
# 10  /gp/profile/amzn1.account.AG27HEMGYJG75H7YZCCZ...
# 11  /gp/profile/amzn1.account.AEACSIHPIHYVDLTNUXBO...
# 12  /gp/profile/amzn1.account.AGPEQZRSHE6IXGVPIMAU...
# 13  /gp/profile/amzn1.account.AEUV6C2INP77HLEXHFUF...

# %%
rev = {'name':profile_name,'ratings':ratings,'date':date}
review_data = pd.DataFrame.from_dict(rev, orient='index')
review_data = review_data.transpose()
pd.set_option('max_colwidth',800)

# %%
review_data['geography'] = 'USA'

# %%
#review_data.drop_duplicates(subset=['name'],inplace=True)
review_data.dropna(inplace=True)

# %%
final = pd.concat([review_data,df1,df2,df3,df4], axis=1)
final.dropna(inplace=True)
final.head()
# Out:
#                name             ratings  \
# 0            Vickie  2.0 out of 5 stars
# 1     guitarwarrior  4.0 out of 5 stars
# 2           Brandon  4.0 out of 5 stars
# 3  David P Peterson  1.0 out of 5 stars
# 4             Amber  3.0 out of 5 stars
#
#                                                date geography  \
# 0  Reviewed in the United States on August 10, 2019       USA
# 1  Reviewed in the United States on January 5, 2019       USA
# 2    Reviewed in the United States on July 18, 2019       USA
# 3  Reviewed in the United States on August 13, 2020       USA
# 4  Reviewed in the United States on August 24, 2019       USA
#
#                                                                                  links  \
# 0  /gp/customer-reviews/R2MDYN7CSIEAZ5/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 1  /gp/customer-reviews/R31QHSMQT58S2Z/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 2  /gp/customer-reviews/R3R5FUG8C17P5P/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 3  /gp/customer-reviews/R25U1AS495T1MV/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 4   /gp/customer-reviews/RG7NMOY35E2XN/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
#
#                                                                                                                                                                                                                                                                                                        reviews  \
# 0                                                                                                                       \n\n  I really wanted to like this . I bought the zesty garlic and it was so hot all I could do is run for the water. Very disappointed. Maybe a different flavor might be better.\n\n
# 1  \n\n  Our family chose this flavor because we all love garlic. Some found the garlic intensity a little weak but it was perfect for my taste. The jerky itself was chewy but not too hard. We like the smaller packages because we don't feel the need to consume the entire product within a few days.\n\n
# 2               \n\n  Overall product is pretty good. Yes some pieces can be pretty tough when you start chewing( doesn't really bother me). Zesty garlic is more of a slow burn, wish the flavor was more initially intense( personal preference). Interested in experimenting with other flavors offered\n\n
# 3                                                                                                                                                    \n\n  Got the Zesty Garlic, was unimpressed. The clove in the ingredients was the only thing I could taste and the beef was not "melt in your mouth".\n\n
# 4                                                                                                                                                                                         \n\n  it’s ok. I wouldn’t say anything fantastic. if it was thinner and crispy like bacon ? it would be perfect.\n\n
#
#                                       tags  \
# 0              \nNot flavorful just hot!\n
# 1  \nTasty. Will try other flavors next.\n
# 2                      \nWould buy again\n
# 3                      \nToo much clove.\n
# 4                                  \nok.\n
#
#                                                                              userid_link
# 0  /gp/profile/amzn1.account.AHXPZVHBSZ57EQGMUWNF6U7U65HQ/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 1  /gp/profile/amzn1.account.AE5D6UZUC6JD55ZAWHV37J5W4AHA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 2  /gp/profile/amzn1.account.AHXDOYOHN3A23CKJQ4JM3TCDEBPA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 3  /gp/profile/amzn1.account.AEQMH6YYDWVL36HN6N42U6D3A7TA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 4  /gp/profile/amzn1.account.AGUUZ6CRSSPZKDXFWPMZ6EICB2YA/ref=cm_cr_arp_d_gw_btm?ie=UTF8

# %%
#user ratings cleaning
def star_clean(df_col):
    new_column = []
    for i in df_col.map(lambda x: x.replace('out of 5 stars', '')):
        x = np.array(i, dtype= object)
        new_column.append(x) 
    return new_column

# %%
final['ratings'] = star_clean(final.ratings)
final.head()
# Out:
#                name ratings                                              date  \
# 0            Vickie    2.0   Reviewed in the United States on August 10, 2019
# 1     guitarwarrior    4.0   Reviewed in the United States on January 5, 2019
# 2           Brandon    4.0     Reviewed in the United States on July 18, 2019
# 3  David P Peterson    1.0   Reviewed in the United States on August 13, 2020
# 4             Amber    3.0   Reviewed in the United States on August 24, 2019
#
#   geography  \
# 0       USA
# 1       USA
# 2       USA
# 3       USA
# 4       USA
#
#                                                                                  links  \
# 0  /gp/customer-reviews/R2MDYN7CSIEAZ5/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 1  /gp/customer-reviews/R31QHSMQT58S2Z/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 2  /gp/customer-reviews/R3R5FUG8C17P5P/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 3  /gp/customer-reviews/R25U1AS495T1MV/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 4   /gp/customer-reviews/RG7NMOY35E2XN/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
#
#                                                                                                                                                                                                                                                                                                        reviews  \
# 0                                                                                                                       \n\n  I really wanted to like this . I bought the zesty garlic and it was so hot all I could do is run for the water. Very disappointed. Maybe a different flavor might be better.\n\n
# 1  \n\n  Our family chose this flavor because we all love garlic. Some found the garlic intensity a little weak but it was perfect for my taste. The jerky itself was chewy but not too hard. We like the smaller packages because we don't feel the need to consume the entire product within a few days.\n\n
# 2               \n\n  Overall product is pretty good. Yes some pieces can be pretty tough when you start chewing( doesn't really bother me). Zesty garlic is more of a slow burn, wish the flavor was more initially intense( personal preference). Interested in experimenting with other flavors offered\n\n
# 3                                                                                                                                                    \n\n  Got the Zesty Garlic, was unimpressed. The clove in the ingredients was the only thing I could taste and the beef was not "melt in your mouth".\n\n
# 4                                                                                                                                                                                         \n\n  it’s ok. I wouldn’t say anything fantastic. if it was thinner and crispy like bacon ? it would be perfect.\n\n
#
#                                       tags  \
# 0              \nNot flavorful just hot!\n
# 1  \nTasty. Will try other flavors next.\n
# 2                      \nWould buy again\n
# 3                      \nToo much clove.\n
# 4                                  \nok.\n
#
#                                                                              userid_link
# 0  /gp/profile/amzn1.account.AHXPZVHBSZ57EQGMUWNF6U7U65HQ/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 1  /gp/profile/amzn1.account.AE5D6UZUC6JD55ZAWHV37J5W4AHA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 2  /gp/profile/amzn1.account.AHXDOYOHN3A23CKJQ4JM3TCDEBPA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 3  /gp/profile/amzn1.account.AEQMH6YYDWVL36HN6N42U6D3A7TA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 4  /gp/profile/amzn1.account.AGUUZ6CRSSPZKDXFWPMZ6EICB2YA/ref=cm_cr_arp_d_gw_btm?ie=UTF8

# %%
def date_conv(d):
    d = str(d)
    x = re.search("on", d)
    d = d[int(x.end()+1):]
    return d

# %%
final['date'] = final['date'].apply(date_conv)
final.head()
# Out:
#                name ratings             date geography  \
# 0            Vickie    2.0   August 10, 2019       USA
# 1     guitarwarrior    4.0   January 5, 2019       USA
# 2           Brandon    4.0     July 18, 2019       USA
# 3  David P Peterson    1.0   August 13, 2020       USA
# 4             Amber    3.0   August 24, 2019       USA
#
#                                                                                  links  \
# 0  /gp/customer-reviews/R2MDYN7CSIEAZ5/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 1  /gp/customer-reviews/R31QHSMQT58S2Z/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 2  /gp/customer-reviews/R3R5FUG8C17P5P/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 3  /gp/customer-reviews/R25U1AS495T1MV/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 4   /gp/customer-reviews/RG7NMOY35E2XN/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
#
#                                                                                                                                                                                                                                                                                                        reviews  \
# 0                                                                                                                       \n\n  I really wanted to like this . I bought the zesty garlic and it was so hot all I could do is run for the water. Very disappointed. Maybe a different flavor might be better.\n\n
# 1  \n\n  Our family chose this flavor because we all love garlic. Some found the garlic intensity a little weak but it was perfect for my taste. The jerky itself was chewy but not too hard. We like the smaller packages because we don't feel the need to consume the entire product within a few days.\n\n
# 2               \n\n  Overall product is pretty good. Yes some pieces can be pretty tough when you start chewing( doesn't really bother me). Zesty garlic is more of a slow burn, wish the flavor was more initially intense( personal preference). Interested in experimenting with other flavors offered\n\n
# 3                                                                                                                                                    \n\n  Got the Zesty Garlic, was unimpressed. The clove in the ingredients was the only thing I could taste and the beef was not "melt in your mouth".\n\n
# 4                                                                                                                                                                                         \n\n  it’s ok. I wouldn’t say anything fantastic. if it was thinner and crispy like bacon ? it would be perfect.\n\n
#
#                                       tags  \
# 0              \nNot flavorful just hot!\n
# 1  \nTasty. Will try other flavors next.\n
# 2                      \nWould buy again\n
# 3                      \nToo much clove.\n
# 4                                  \nok.\n
#
#                                                                              userid_link
# 0  /gp/profile/amzn1.account.AHXPZVHBSZ57EQGMUWNF6U7U65HQ/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 1  /gp/profile/amzn1.account.AE5D6UZUC6JD55ZAWHV37J5W4AHA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 2  /gp/profile/amzn1.account.AHXDOYOHN3A23CKJQ4JM3TCDEBPA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 3  /gp/profile/amzn1.account.AEQMH6YYDWVL36HN6N42U6D3A7TA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 4  /gp/profile/amzn1.account.AGUUZ6CRSSPZKDXFWPMZ6EICB2YA/ref=cm_cr_arp_d_gw_btm?ie=UTF8

# %%
def customerid_clean(df_col):
    new_column = []
    for i in df_col.map(lambda x: x.replace('/gp/customer-reviews/', '')[0:14]):
        x = np.array(i, dtype= object)
        new_column.append(x) 
    return new_column

# %%
final['customer_id'] = customerid_clean(final.links)
final.head()
# Out:
#                name ratings             date geography  \
# 0            Vickie    2.0   August 10, 2019       USA
# 1     guitarwarrior    4.0   January 5, 2019       USA
# 2           Brandon    4.0     July 18, 2019       USA
# 3  David P Peterson    1.0   August 13, 2020       USA
# 4             Amber    3.0   August 24, 2019       USA
#
#                                                                                  links  \
# 0  /gp/customer-reviews/R2MDYN7CSIEAZ5/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 1  /gp/customer-reviews/R31QHSMQT58S2Z/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 2  /gp/customer-reviews/R3R5FUG8C17P5P/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 3  /gp/customer-reviews/R25U1AS495T1MV/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 4   /gp/customer-reviews/RG7NMOY35E2XN/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
#
#                                                                                                                                                                                                                                                                                                        reviews  \
# 0                                                                                                                       \n\n  I really wanted to like this . I bought the zesty garlic and it was so hot all I could do is run for the water. Very disappointed. Maybe a different flavor might be better.\n\n
# 1  \n\n  Our family chose this flavor because we all love garlic. Some found the garlic intensity a little weak but it was perfect for my taste. The jerky itself was chewy but not too hard. We like the smaller packages because we don't feel the need to consume the entire product within a few days.\n\n
# 2               \n\n  Overall product is pretty good. Yes some pieces can be pretty tough when you start chewing( doesn't really bother me). Zesty garlic is more of a slow burn, wish the flavor was more initially intense( personal preference). Interested in experimenting with other flavors offered\n\n
# 3                                                                                                                                                    \n\n  Got the Zesty Garlic, was unimpressed. The clove in the ingredients was the only thing I could taste and the beef was not "melt in your mouth".\n\n
# 4                                                                                                                                                                                         \n\n  it’s ok. I wouldn’t say anything fantastic. if it was thinner and crispy like bacon ? it would be perfect.\n\n
#
#                                       tags  \
# 0              \nNot flavorful just hot!\n
# 1  \nTasty. Will try other flavors next.\n
# 2                      \nWould buy again\n
# 3                      \nToo much clove.\n
# 4                                  \nok.\n
#
#                                                                              userid_link  \
# 0  /gp/profile/amzn1.account.AHXPZVHBSZ57EQGMUWNF6U7U65HQ/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 1  /gp/profile/amzn1.account.AE5D6UZUC6JD55ZAWHV37J5W4AHA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 2  /gp/profile/amzn1.account.AHXDOYOHN3A23CKJQ4JM3TCDEBPA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 3  /gp/profile/amzn1.account.AEQMH6YYDWVL36HN6N42U6D3A7TA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 4  /gp/profile/amzn1.account.AGUUZ6CRSSPZKDXFWPMZ6EICB2YA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
#
#       customer_id
# 0  R2MDYN7CSIEAZ5
# 1  R31QHSMQT58S2Z
# 2  R3R5FUG8C17P5P
# 3  R25U1AS495T1MV
# 4  RG7NMOY35E2XN/

# %%
def productid_clean(df_col):
    new_column = []
    for i in df_col.map(lambda x: x.replace(' ','')[-10:]):
        x = np.array(i, dtype= object)
        new_column.append(x) 
    return new_column

# %%
final['product_id'] = productid_clean(final.links)
final.head()
# Out:
#                name ratings             date geography  \
# 0            Vickie    2.0   August 10, 2019       USA
# 1     guitarwarrior    4.0   January 5, 2019       USA
# 2           Brandon    4.0     July 18, 2019       USA
# 3  David P Peterson    1.0   August 13, 2020       USA
# 4             Amber    3.0   August 24, 2019       USA
#
#                                                                                  links  \
# 0  /gp/customer-reviews/R2MDYN7CSIEAZ5/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 1  /gp/customer-reviews/R31QHSMQT58S2Z/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 2  /gp/customer-reviews/R3R5FUG8C17P5P/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 3  /gp/customer-reviews/R25U1AS495T1MV/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 4   /gp/customer-reviews/RG7NMOY35E2XN/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
#
#                                                                                                                                                                                                                                                                                                        reviews  \
# 0                                                                                                                       \n\n  I really wanted to like this . I bought the zesty garlic and it was so hot all I could do is run for the water. Very disappointed. Maybe a different flavor might be better.\n\n
# 1  \n\n  Our family chose this flavor because we all love garlic. Some found the garlic intensity a little weak but it was perfect for my taste. The jerky itself was chewy but not too hard. We like the smaller packages because we don't feel the need to consume the entire product within a few days.\n\n
# 2               \n\n  Overall product is pretty good. Yes some pieces can be pretty tough when you start chewing( doesn't really bother me). Zesty garlic is more of a slow burn, wish the flavor was more initially intense( personal preference). Interested in experimenting with other flavors offered\n\n
# 3                                                                                                                                                    \n\n  Got the Zesty Garlic, was unimpressed. The clove in the ingredients was the only thing I could taste and the beef was not "melt in your mouth".\n\n
# 4                                                                                                                                                                                         \n\n  it’s ok. I wouldn’t say anything fantastic. if it was thinner and crispy like bacon ? it would be perfect.\n\n
#
#                                       tags  \
# 0              \nNot flavorful just hot!\n
# 1  \nTasty. Will try other flavors next.\n
# 2                      \nWould buy again\n
# 3                      \nToo much clove.\n
# 4                                  \nok.\n
#
#                                                                              userid_link  \
# 0  /gp/profile/amzn1.account.AHXPZVHBSZ57EQGMUWNF6U7U65HQ/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 1  /gp/profile/amzn1.account.AE5D6UZUC6JD55ZAWHV37J5W4AHA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 2  /gp/profile/amzn1.account.AHXDOYOHN3A23CKJQ4JM3TCDEBPA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 3  /gp/profile/amzn1.account.AEQMH6YYDWVL36HN6N42U6D3A7TA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 4  /gp/profile/amzn1.account.AGUUZ6CRSSPZKDXFWPMZ6EICB2YA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
#
#       customer_id  product_id
# 0  R2MDYN7CSIEAZ5  B07B47WHCC
# 1  R31QHSMQT58S2Z  B07B47WHCC
# 2  R3R5FUG8C17P5P  B07B47WHCC
# 3  R25U1AS495T1MV  B07B47WHCC
# 4  RG7NMOY35E2XN/  B07B47WHCC

# %%
def userid_clean(df_col):
    new_column = []
    for i in df_col.map(lambda x: x.replace('/ref=cm_cr_arp_d_gw_btm?ie=UTF8', '')[26:]):
        x = np.array(i, dtype= object)
        new_column.append(x) 
    return new_column

# %%
final['user_id'] = userid_clean(final.userid_link)
final.head()
# Out:
#                name ratings             date geography  \
# 0            Vickie    2.0   August 10, 2019       USA
# 1     guitarwarrior    4.0   January 5, 2019       USA
# 2           Brandon    4.0     July 18, 2019       USA
# 3  David P Peterson    1.0   August 13, 2020       USA
# 4             Amber    3.0   August 24, 2019       USA
#
#                                                                                  links  \
# 0  /gp/customer-reviews/R2MDYN7CSIEAZ5/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 1  /gp/customer-reviews/R31QHSMQT58S2Z/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 2  /gp/customer-reviews/R3R5FUG8C17P5P/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 3  /gp/customer-reviews/R25U1AS495T1MV/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 4   /gp/customer-reviews/RG7NMOY35E2XN/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
#
#                                                                                                                                                                                                                                                                                                        reviews  \
# 0                                                                                                                       \n\n  I really wanted to like this . I bought the zesty garlic and it was so hot all I could do is run for the water. Very disappointed. Maybe a different flavor might be better.\n\n
# 1  \n\n  Our family chose this flavor because we all love garlic. Some found the garlic intensity a little weak but it was perfect for my taste. The jerky itself was chewy but not too hard. We like the smaller packages because we don't feel the need to consume the entire product within a few days.\n\n
# 2               \n\n  Overall product is pretty good. Yes some pieces can be pretty tough when you start chewing( doesn't really bother me). Zesty garlic is more of a slow burn, wish the flavor was more initially intense( personal preference). Interested in experimenting with other flavors offered\n\n
# 3                                                                                                                                                    \n\n  Got the Zesty Garlic, was unimpressed. The clove in the ingredients was the only thing I could taste and the beef was not "melt in your mouth".\n\n
# 4                                                                                                                                                                                         \n\n  it’s ok. I wouldn’t say anything fantastic. if it was thinner and crispy like bacon ? it would be perfect.\n\n
#
#                                       tags  \
# 0              \nNot flavorful just hot!\n
# 1  \nTasty. Will try other flavors next.\n
# 2                      \nWould buy again\n
# 3                      \nToo much clove.\n
# 4                                  \nok.\n
#
#                                                                              userid_link  \
# 0  /gp/profile/amzn1.account.AHXPZVHBSZ57EQGMUWNF6U7U65HQ/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 1  /gp/profile/amzn1.account.AE5D6UZUC6JD55ZAWHV37J5W4AHA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 2  /gp/profile/amzn1.account.AHXDOYOHN3A23CKJQ4JM3TCDEBPA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 3  /gp/profile/amzn1.account.AEQMH6YYDWVL36HN6N42U6D3A7TA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 4  /gp/profile/amzn1.account.AGUUZ6CRSSPZKDXFWPMZ6EICB2YA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
#
#       customer_id  product_id                       user_id
# 0  R2MDYN7CSIEAZ5  B07B47WHCC  AHXPZVHBSZ57EQGMUWNF6U7U65HQ
# 1  R31QHSMQT58S2Z  B07B47WHCC  AE5D6UZUC6JD55ZAWHV37J5W4AHA
# 2  R3R5FUG8C17P5P  B07B47WHCC  AHXDOYOHN3A23CKJQ4JM3TCDEBPA
# 3  R25U1AS495T1MV  B07B47WHCC  AEQMH6YYDWVL36HN6N42U6D3A7TA
# 4  RG7NMOY35E2XN/  B07B47WHCC  AGUUZ6CRSSPZKDXFWPMZ6EICB2YA

# %%
#cleaning reviews
final['reviews_clean'] = final['reviews'].apply(lambda x: " ".join(word.lower() for word in x.split()))
final['tags_clean'] = final['tags'].apply(lambda x: " ".join(word.lower() for word in x.split()))
final.head()
# Out:
#                name ratings             date geography  \
# 0            Vickie    2.0   August 10, 2019       USA
# 1     guitarwarrior    4.0   January 5, 2019       USA
# 2           Brandon    4.0     July 18, 2019       USA
# 3  David P Peterson    1.0   August 13, 2020       USA
# 4             Amber    3.0   August 24, 2019       USA
#
#                                                                                  links  \
# 0  /gp/customer-reviews/R2MDYN7CSIEAZ5/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 1  /gp/customer-reviews/R31QHSMQT58S2Z/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 2  /gp/customer-reviews/R3R5FUG8C17P5P/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 3  /gp/customer-reviews/R25U1AS495T1MV/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
# 4   /gp/customer-reviews/RG7NMOY35E2XN/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07B47WHCC
#
#                                                                                                                                                                                                                                                                                                        reviews  \
# 0                                                                                                                       \n\n  I really wanted to like this . I bought the zesty garlic and it was so hot all I could do is run for the water. Very disappointed. Maybe a different flavor might be better.\n\n
# 1  \n\n  Our family chose this flavor because we all love garlic. Some found the garlic intensity a little weak but it was perfect for my taste. The jerky itself was chewy but not too hard. We like the smaller packages because we don't feel the need to consume the entire product within a few days.\n\n
# 2               \n\n  Overall product is pretty good. Yes some pieces can be pretty tough when you start chewing( doesn't really bother me). Zesty garlic is more of a slow burn, wish the flavor was more initially intense( personal preference). Interested in experimenting with other flavors offered\n\n
# 3                                                                                                                                                    \n\n  Got the Zesty Garlic, was unimpressed. The clove in the ingredients was the only thing I could taste and the beef was not "melt in your mouth".\n\n
# 4                                                                                                                                                                                         \n\n  it’s ok. I wouldn’t say anything fantastic. if it was thinner and crispy like bacon ? it would be perfect.\n\n
#
#                                       tags  \
# 0              \nNot flavorful just hot!\n
# 1  \nTasty. Will try other flavors next.\n
# 2                      \nWould buy again\n
# 3                      \nToo much clove.\n
# 4                                  \nok.\n
#
#                                                                              userid_link  \
# 0  /gp/profile/amzn1.account.AHXPZVHBSZ57EQGMUWNF6U7U65HQ/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 1  /gp/profile/amzn1.account.AE5D6UZUC6JD55ZAWHV37J5W4AHA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 2  /gp/profile/amzn1.account.AHXDOYOHN3A23CKJQ4JM3TCDEBPA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 3  /gp/profile/amzn1.account.AEQMH6YYDWVL36HN6N42U6D3A7TA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
# 4  /gp/profile/amzn1.account.AGUUZ6CRSSPZKDXFWPMZ6EICB2YA/ref=cm_cr_arp_d_gw_btm?ie=UTF8
#
#       customer_id  product_id                       user_id  \
# 0  R2MDYN7CSIEAZ5  B07B47WHCC  AHXPZVHBSZ57EQGMUWNF6U7U65HQ
# 1  R31QHSMQT58S2Z  B07B47WHCC  AE5D6UZUC6JD55ZAWHV37J5W4AHA
# 2  R3R5FUG8C17P5P  B07B47WHCC  AHXDOYOHN3A23CKJQ4JM3TCDEBPA
# 3  R25U1AS495T1MV  B07B47WHCC  AEQMH6YYDWVL36HN6N42U6D3A7TA
# 4  RG7NMOY35E2XN/  B07B47WHCC  AGUUZ6CRSSPZKDXFWPMZ6EICB2YA
#
#                                                                                                                                                                                                                                                                                        reviews_clean  \
# 0                                                                                                                       i really wanted to like this . i bought the zesty garlic and it was so hot all i could do is run for the water. very disappointed. maybe a different flavor might be better.
# 1  our family chose this flavor because we all love garlic. some found the garlic intensity a little weak but it was perfect for my taste. the jerky itself was chewy but not too hard. we like the smaller packages because we don't feel the need to consume the entire product within a few days.
# 2               overall product is pretty good. yes some pieces can be pretty tough when you start chewing( doesn't really bother me). zesty garlic is more of a slow burn, wish the flavor was more initially intense( personal preference). interested in experimenting with other flavors offered
# 3                                                                                                                                                    got the zesty garlic, was unimpressed. the clove in the ingredients was the only thing i could taste and the beef was not "melt in your mouth".
# 4                                                                                                                                                                                         it’s ok. i wouldn’t say anything fantastic. if it was thinner and crispy like bacon ? it would be perfect.
#
#                             tags_clean
# 0              not flavorful just hot!
# 1  tasty. will try other flavors next.
# 2                      would buy again
# 3                      too much clove.
# 4                                  ok.

# %%
final.drop(['reviews','tags','links','userid_link'],axis=1,inplace=True)
final.head()
# Out:
#                name ratings             date geography     customer_id  \
# 0            Vickie    2.0   August 10, 2019       USA  R2MDYN7CSIEAZ5
# 1     guitarwarrior    4.0   January 5, 2019       USA  R31QHSMQT58S2Z
# 2           Brandon    4.0     July 18, 2019       USA  R3R5FUG8C17P5P
# 3  David P Peterson    1.0   August 13, 2020       USA  R25U1AS495T1MV
# 4             Amber    3.0   August 24, 2019       USA  RG7NMOY35E2XN/
#
#    product_id                       user_id  \
# 0  B07B47WHCC  AHXPZVHBSZ57EQGMUWNF6U7U65HQ
# 1  B07B47WHCC  AE5D6UZUC6JD55ZAWHV37J5W4AHA
# 2  B07B47WHCC  AHXDOYOHN3A23CKJQ4JM3TCDEBPA
# 3  B07B47WHCC  AEQMH6YYDWVL36HN6N42U6D3A7TA
# 4  B07B47WHCC  AGUUZ6CRSSPZKDXFWPMZ6EICB2YA
#
#                                                                                                                                                                                                                                                                                        reviews_clean  \
# 0                                                                                                                       i really wanted to like this . i bought the zesty garlic and it was so hot all i could do is run for the water. very disappointed. maybe a different flavor might be better.
# 1  our family chose this flavor because we all love garlic. some found the garlic intensity a little weak but it was perfect for my taste. the jerky itself was chewy but not too hard. we like the smaller packages because we don't feel the need to consume the entire product within a few days.
# 2               overall product is pretty good. yes some pieces can be pretty tough when you start chewing( doesn't really bother me). zesty garlic is more of a slow burn, wish the flavor was more initially intense( personal preference). interested in experimenting with other flavors offered
# 3                                                                                                                                                    got the zesty garlic, was unimpressed. the clove in the ingredients was the only thing i could taste and the beef was not "melt in your mouth".
# 4                                                                                                                                                                                         it’s ok. i wouldn’t say anything fantastic. if it was thinner and crispy like bacon ? it would be perfect.
#
#                             tags_clean
# 0              not flavorful just hot!
# 1  tasty. will try other flavors next.
# 2                      would buy again
# 3                      too much clove.
# 4                                  ok.

# %%
final.to_csv('final2.csv',index=False,header=True)

# %%
final_list = []
for i in range(len(data_asin)):
    response = Searchasin(data_asin[i])
    soup = BeautifulSoup(response.content)
    product_name = soup.find('span',{'class':'a-size-large product-title-word-break'}).text.strip()
    try:
        product_rating = soup.findAll('span',{'class':'a-icon-alt'})[0].text.replace(' out of 5 stars','').replace('Previous page of related Sponsored Products','').strip()
    except AttributeError:
        product_rating = ''
    except IndexError:
        product_rating = ''
    try:
        product_price = soup.findAll('table',{'class':'a-lineitem'})[0].tr.span.text[1:]
    except IndexError:
        product_price = ''
    try:
        product_review = soup.findAll('span',{'id':'acrCustomerReviewText'})[0].text.replace('ratings','').strip()
    except IndexError:
        product_review = ''
    try:
        brand = soup.find('a',{'id':'bylineInfo'}).text.strip()
    except IndexError:
        brand = ''
        
    final=[product_name,product_rating,product_price,product_review,brand]
    final_list.append(final)
# Out:
# https://www.amazon.com/dp/B07B47WHCC

# %%
df = pd.DataFrame(final_list,columns=['name','rating','price','review','brand'])
df['link'] = 'https://www.amazon.com'

# %%
df['user_id'] = data_asin

# %%
df.head()
# Out:
#                                                                                                                                                                                         name  \
# 0  Stryve Biltong, Beef Jerky without the Junky. 16g Protein, Sugar Free, No Carbs, Gluten Free, No Nitrates, No MSG, No Preservatives. Keto and Paleo Friendly. Zesty Garlic, 2.25oz 4-Pack
#
#   rating  price review                                  brand  \
# 0    3.6  26.99     29  Visit the Stryve Protein Snacks Store
#
#                      link     user_id
# 0  https://www.amazon.com  B07B47WHCC
